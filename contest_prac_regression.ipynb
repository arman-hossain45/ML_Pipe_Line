# %% [markdown]
# <a href="https://colab.research.google.com/github/arman-hossain45/ML_Pipe_Line/blob/main/contest_prac_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Regression related problem pipeline এখানে মূলত regression related একটি CSV এর problem এর full pipeline এর কোড করা হয়েছে, যেখানে বিভিন্ন model apply করা হয়েছে এবং সবকিছু দেখা হয়েছে।

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.preprocessing import OneHotEncoder,StandardScaler,LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression,ElasticNet,SGDRegressor,Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import VotingRegressor,StackingRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
train_df=pd.read_csv("dataset.csv")
test_df = pd.read_csv("test.csv")
# keep a copy of the test IDs for submission
test_ids = test_df['PID'].copy()
test_df=test_df.drop(columns=['PID'])

# %%
test_df.head(3)
# Out:
#    Order  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0   1358           70        RM           NaN      5100   Pave  Grvl
# 1   2368          160        RM          21.0      1890   Pave   NaN
# 2   2823           60        RL          62.0      7162   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Screen Porch Pool Area Pool QC  Fence  \
# 0       Reg          Lvl    AllPub  ...            0         0     NaN  MnPrv
# 1       Reg          Lvl    AllPub  ...            0         0     NaN    NaN
# 2       Reg          Lvl    AllPub  ...            0         0     NaN    NaN
#
#   Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition
# 0          NaN        0       6     2008         WD          Normal
# 1          NaN        0       7     2006         WD          Normal
# 2          NaN        0       5     2006         WD          Normal
#
# [3 rows x 80 columns]

# %%
train_df.head(3)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   1323  902405070           70        RM          60.0     10800   Pave
# 1   2476  531376030           60        RL          65.0      7800   Pave
# 2   2091  906201022           20        RL         114.0     10357   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC Fence Misc Feature  \
# 0   NaN       Reg          Lvl  ...         0     NaN   NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN   NaN          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN   NaN          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0        0      12    2008       WD           Normal     184000
# 1        0       4    2006       WD           Normal     184000
# 2        0       5    2007       WD           Normal     179900
#
# [3 rows x 82 columns]

# %%
test_df.head(5)
# Out:
#    Order  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0   1358           70        RM           NaN      5100   Pave  Grvl
# 1   2368          160        RM          21.0      1890   Pave   NaN
# 2   2823           60        RL          62.0      7162   Pave   NaN
# 3   2127           20        RL          60.0      8070   Pave   NaN
# 4   1545           30        RM          50.0      7000   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Screen Porch Pool Area Pool QC  Fence  \
# 0       Reg          Lvl    AllPub  ...            0         0     NaN  MnPrv
# 1       Reg          Lvl    AllPub  ...            0         0     NaN    NaN
# 2       Reg          Lvl    AllPub  ...            0         0     NaN    NaN
#  81  SalePrice        1758 non-null   int64
# dtypes: float64(11), int64(28), object(43)
# memory usage: 1.1+ MB

# %%
train_df.shape
# Out:
# (1758, 82)

# %%
train_df.isnull().sum()
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      308
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
#এইখানে সবগুলা কলামের null value দেখাচ্ছে না। এখন যেসব কলামে null value আছে তা দেখার জন্য আমরা নিচের কোডটি লিখবো:
null_values = train_df.isnull().sum()
null_values[null_values > 0]
# Out:
# Lot Frontage       308
# Alley             1636
# Mas Vnr Type      1055
# Mas Vnr Area        12
# Bsmt Qual           42
# Bsmt Cond           42
# Bsmt Exposure       44
# BsmtFin Type 1      42
# BsmtFin SF 1         1
# BsmtFin Type 2      42
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Bsmt Full Bath       1
# Bsmt Half Bath       1
# Fireplace Qu       877
# Garage Type         98
# Garage Yr Blt       99
# Garage Finish       99
# Garage Cars          1
# Garage Area          1
# Garage Qual         99
# Garage Cond         99
# Pool QC           1752
# Fence             1411
# Misc Feature      1692
# dtype: int64

# %%
#এইখানে যাদের missing value অনেক, যেসব কলামের ওই কলামগুলো আমরা delete করে দেব।
#একটা কলাম ডিলিট করতে চাইলে এই কোড লিখবো: df.drop("Car_ID", axis=1, inplace=True)
train_df.drop(
    columns=['Misc Feature', 'Pool QC', 'Alley','Mas Vnr Type','Fireplace Qu'],
    inplace=True
)

# %%
train_df.shape
# Out:
# (1758, 77)

# %%
#Duplicate value আছে কিনা তা আমরা চেক করলাম।

train_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
train_df.drop_duplicates(inplace=True)

# %% [markdown]
# ট্রেন ডাটা সেটের **numerical** column এবং **categorical** column আমরা আলাদা করব।

# %%
num=train_df.select_dtypes(include=['int64','float64'])
cat = train_df.select_dtypes(include=['object'])

# %%
cat
# Out:
#      MS Zoning Street Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0           RM   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 1           RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 3           RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 4      C (all)   Pave       Reg          Lvl    AllPub     Inside        Gtl
# ...        ...    ...       ...          ...       ...        ...        ...
# 1753        RL   Pave       IR1          Lvl    AllPub        FR2        Gtl
# 1754        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 1755        FV   Pave       IR1          Lvl    AllPub     Inside        Gtl
# 1756        RM   Pave       Reg          Lvl    AllPub     Corner        Gtl
# 1757        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2  ... Kitchen Qual Functional  \
# 0         OldTown        Norm        Norm  ...           TA        Typ
# 1         SawyerW        Norm        Norm  ...           Gd        Typ
# 2         SawyerW       Feedr        Norm  ...           Gd        Typ
# 3         Edwards        Norm        Norm  ...           TA        Mod
# 4          IDOTRR        Norm        Norm  ...           TA       Min2
# ...           ...         ...         ...  ...          ...        ...
# 1753      Gilbert        Norm        Norm  ...           TA        Mod
# 1754      Gilbert        RRAn        Norm  ...           Gd        Typ
# 1755      Somerst        Norm        Norm  ...           Gd        Typ
# 1756      OldTown      Artery        Norm  ...           Ex        Typ
# 1757      CollgCr        Norm        Norm  ...           TA        Typ
#
#      Garage Type Garage Finish Garage Qual Garage Cond Paved Drive  Fence  \
# 0         Detchd           Unf          TA          Fa           Y    NaN
# 1         Attchd           Fin          TA          TA           Y    NaN
# 2         Attchd           Fin          TA          TA           Y    NaN
# 3        BuiltIn           Unf          TA          TA           Y    NaN
# 4            NaN           NaN         NaN         NaN           Y    NaN
# ...          ...           ...         ...         ...         ...    ...
# 1753      2Types           Unf          TA          TA           N    NaN
# 1754      Attchd           Fin          TA          TA           Y    NaN
# 1755      Attchd           RFn          TA          TA           Y    NaN
# 1756      Detchd           Unf          Fa          Fa           N    NaN
# 1757      Detchd           Fin          TA          TA           Y  MnPrv
#
#      Sale Type Sale Condition
# 0          WD          Normal
# 1          WD          Normal
# 2          WD          Normal
# 3          WD          Family
# 4          WD         Abnorml
# ...        ...            ...
# 1753       WD          Normal
# 1754       WD          Normal
# 1755       WD          Normal
# 1756       WD          Normal
# 1757       WD          Normal
#
# [1758 rows x 38 columns]

# %%
#ক্যাটেগরিকাল কলাম যদি অনেক থাকে, তাহলে লেবেল এনকোডার দেখার জন্য এই কোডটা দরকার:

for col in cat:
    print(f"\nColumn: {col}")
    print("Unique count:", train_df[col].nunique())
    print("Values:", train_df[col].unique())
# Out:
# Column: MS Zoning
# Unique count: 6
# Values: ['RM' 'RL' 'C (all)' 'FV' 'RH' 'A (agr)']
#
# Column: Street
# Unique count: 2
# Values: ['Pave' 'Grvl']
#
# Column: Lot Shape
# Unique count: 4
# Values: ['Reg' 'IR1' 'IR2' 'IR3']
#
# Column: Land Contour
# Unique count: 4
# Values: ['Lvl' 'HLS' 'Bnk' 'Low']
#
# Column: Utilities
# Unique count: 3
# Values: ['AllPub' 'NoSewr' 'NoSeWa']
#
# Column: Lot Config
# Unique count: 5
# Values: ['Inside' 'Corner' 'CulDSac' 'FR2' 'FR3']
#
# Column: Land Slope
# Unique count: 3
# Values: ['Gtl' 'Mod' 'Sev']
#
# Column: Neighborhood
# Unique count: 28
# Values: ['OldTown' 'SawyerW' 'Edwards' 'IDOTRR' 'NWAmes' 'NAmes' 'NridgHt'
#  'Mitchel' 'SWISU' 'BrkSide' 'Gilbert' 'Timber' 'Blmngtn' 'Crawfor'
#  'Somerst' 'Veenker' 'NoRidge' 'MeadowV' 'BrDale' 'StoneBr' 'CollgCr'
#  'Sawyer' 'ClearCr' 'NPkVill' 'Blueste' 'Greens' 'Landmrk' 'GrnHill']
#
# Column: Condition 1
# Unique count: 9
# Values: ['Norm' 'Feedr' 'RRAn' 'PosN' 'PosA' 'RRNn' 'RRNe' 'RRAe' 'Artery']
#
# Column: Condition 2
# Unique count: 6
# Values: ['Norm' 'PosA' 'Feedr' 'PosN' 'Artery' 'RRAn']
#
# Column: Bldg Type
# Unique count: 5
# Values: ['1Fam' '2fmCon' 'TwnhsE' 'Twnhs' 'Duplex']
#
# Column: House Style
# Unique count: 8
# Values: ['2Story' '1Story' '1.5Fin' 'SFoyer' '2.5Fin' 'SLvl' '2.5Unf' '1.5Unf']
#
# Column: Roof Style
# Unique count: 6
# Values: ['Gable' 'Hip' 'Gambrel' 'Flat' 'Mansard' 'Shed']
#
# Column: Roof Matl
# Unique count: 6
# Values: ['CompShg' 'WdShake' 'Tar&Grv' 'WdShngl' 'Membran' 'Metal']
#
# Column: Exterior 1st
# Unique count: 15
# Values: ['Wd Sdng' 'VinylSd' 'HdBoard' 'BrkFace' 'WdShing' 'Plywood' 'MetalSd'
#  'Stone' 'CemntBd' 'AsbShng' 'BrkComm' 'Stucco' 'ImStucc' 'CBlock'
#  'AsphShn']
#
# Column: Exterior 2nd
# Unique count: 15
# Values: ['Wd Shng' 'VinylSd' 'HdBoard' 'Wd Sdng' 'Plywood' 'MetalSd' 'Stucco'
#  'BrkFace' 'CmentBd' 'AsbShng' 'Brk Cmn' 'ImStucc' 'Stone' 'CBlock'
#  'AsphShn']
#
# Column: Exter Qual
# Unique count: 4
# Values: ['TA' 'Gd' 'Fa' 'Ex']
#
# Column: Exter Cond
# Unique count: 5
# Values: ['TA' 'Fa' 'Gd' 'Ex' 'Po']
#
# Column: Foundation
# Unique count: 6
# Values: ['BrkTil' 'PConc' 'CBlock' 'Slab' 'Stone' 'Wood']
#
# Column: Bsmt Qual
# Unique count: 5
# Values: ['TA' 'Gd' 'Po' 'Ex' 'Fa' nan]
#
# Column: Bsmt Cond
# Unique count: 5
# Values: ['TA' 'Fa' nan 'Gd' 'Ex' 'Po']
#
# Column: Bsmt Exposure
# Unique count: 4
# Values: ['Mn' 'No' 'Av' 'Gd' nan]
#
# Column: BsmtFin Type 1
# Unique count: 6
# Values: ['Unf' 'GLQ' 'LwQ' 'Rec' 'BLQ' 'ALQ' nan]
#
# Column: BsmtFin Type 2
# Unique count: 6
# Values: ['Unf' 'GLQ' 'LwQ' nan 'ALQ' 'BLQ' 'Rec']
#
# Column: Heating
# Unique count: 6
# Values: ['GasW' 'GasA' 'Wall' 'OthW' 'Grav' 'Floor']
#
# Column: Heating QC
# Unique count: 5
# Values: ['Gd' 'Ex' 'TA' 'Fa' 'Po']
#
# Column: Central Air
# Unique count: 2
# Values: ['Y' 'N']
#
# Column: Electrical
# Unique count: 5
# Values: ['SBrkr' 'FuseA' 'FuseF' 'FuseP' 'Mix']
#
# Column: Kitchen Qual
# Unique count: 4
# Values: ['TA' 'Gd' 'Ex' 'Fa']
#
# Column: Functional
# Unique count: 8
# Values: ['Typ' 'Mod' 'Min2' 'Maj1' 'Min1' 'Maj2' 'Sal' 'Sev']
#
# Column: Garage Type
# Unique count: 6
# Values: ['Detchd' 'Attchd' 'BuiltIn' nan 'Basment' 'CarPort' '2Types']
#
# Column: Garage Finish
# Unique count: 3
# Values: ['Unf' 'Fin' nan 'RFn']
#
# Column: Garage Qual
# Unique count: 5
# Values: ['TA' nan 'Po' 'Fa' 'Gd' 'Ex']
#
# Column: Garage Cond
# Unique count: 5
# Values: ['Fa' 'TA' nan 'Gd' 'Po' 'Ex']
#
# Column: Paved Drive
# Unique count: 3
# Values: ['Y' 'N' 'P']
#
# Column: Fence
# Unique count: 4
# Values: [nan 'MnPrv' 'GdPrv' 'GdWo' 'MnWw']
#
# Column: Sale Type
# Unique count: 9
# Values: ['WD ' 'COD' 'ConLD' 'ConLI' 'New' 'ConLw' 'CWD' 'Oth' 'Con']
#
# Column: Sale Condition
# Unique count: 6
# Values: ['Normal' 'Family' 'Abnorml' 'Partial' 'AdjLand' 'Alloca']

# %% [markdown]
# See the data distribution in details

# %%
plt.figure(figsize=(15,15))
train_df[num.columns].hist(bins=20,figsize=(15,15))
plt.title("Numerical data distribution in details ")
plt.tight_layout()
plt.show()

# %%
# see all the data kde to decide the missing value handeling terms
for col in num.columns:
  plt.figure(figsize=(8,6))
  sns.histplot(train_df[col],kde=True,bins=20)
  plt.title(f"{col}")
  plt.tight_layout()
  plt.show()

# %% [markdown]
# এখন দেখব আমাদের data-তে কোন outlier আছে কিনা।

# %%
plt.figure(figsize=(15,15))
train_df[num.columns].boxplot()
plt.tight_layout()
plt.show()

# %% [markdown]
# Outlier handle করবো function এর মাধ্যমে।

# %%
def handle_outlier(df, col):

    df = df.copy()

    # Calculate Q1 and Q3
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)

    # Calculate IQR
    IQR = q3 - q1

    # Calculate lower and upper bounds
    lower = q1 - 1.5 * IQR
    upper = q3 + 1.5 * IQR

    # See number of outliers
    outlier = df[(df[col] < lower) | (df[col] > upper)]
    print(f"Number of outliers in {col}: {len(outlier)}")

    # Handle outliers using clipping
    df[col] = df[col].clip(lower=lower, upper=upper)

    return df

# %%
num
# Out:
#       Order        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0      1323  902405070           70          60.0     10800             7
# 1      2476  531376030           60          65.0      7800             7
# 2      2091  906201022           20         114.0     10357             7
# 3      2734  905403050           50          62.0      6488             5
# 4      2882  911175440          190          50.0      9000             5
# ...     ...        ...          ...           ...       ...           ...
# 1753   1639  527226040          190         195.0     41600             5
# 1754   1096  528290090           60           NaN      7750             7
# 1755   1131  528490080           60          64.0      8791             6
# 1756   1295  902109160           50          81.0      7308             5
# 1757    861  907227110           85          60.0      7200             5
#
#       Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  ...  \
# 0                7        1890            1999           0.0  ...
# 1                5        2005            2005         172.0  ...
# 2                5        1990            1991           0.0  ...
# 3                5        1942            1950           0.0  ...
# 4                6        1951            1951           0.0  ...
# ...            ...         ...             ...           ...  ...
# 1753             5        1969            1990           0.0  ...
# 1754             5        2002            2002           NaN  ...
# 1755             5        2003            2003           0.0  ...
# 1756             5        1920            1950           0.0  ...
# 1757             8        1972            2003           0.0  ...
#
#       Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# 0                0            299               0           0             0
# 1              144            101               0           0             0
# 2                0            244               0           0             0
# 3              264              0               0           0             0
# 4                0              0               0           0             0
# ...            ...            ...             ...         ...           ...
# 1753           144              0               0           0             0
# 1754           100             35               0           0             0
# 1755           216             56               0           0             0
# 1756             0              0             236           0             0
# 1757           192              0               0           0             0
#
#       Pool Area  Misc Val  Mo Sold  Yr Sold  SalePrice
# 0             0         0       12     2008     184000
# 1             0         0        4     2006     184000
# 2             0         0        5     2007     179900
# 3             0         0        3     2006     128000
# 4             0         0       10     2006     115000
# ...         ...       ...      ...      ...        ...
# 1753          0         0       11     2007     155000
# 1754          0         0        4     2008     176000
# 1755          0         0        5     2008     207500
# 1756          0         0        6     2008     122250
# 1757          0         0        4     2009     133900
#
# [1758 rows x 39 columns]

# %%
train_df = handle_outlier(train_df, 'Lot Frontage')
train_df = handle_outlier(train_df, 'Lot Area')
train_df = handle_outlier(train_df, 'Wood Deck SF')
# Out:
# Number of outliers in Lot Frontage: 105
# Number of outliers in Lot Area: 81
# Number of outliers in Wood Deck SF: 39

# %% [markdown]
# Separate X and Y.

# %%
x=train_df.drop(columns=['SalePrice'])
y=train_df['SalePrice']

# %%
y
# Out:
# 0       184000
# 1       184000
# 2       179900
# 3       128000
# 4       115000
#          ...
# 1753    155000
# 1754    176000
# 1755    207500
# 1756    122250
# 1757    133900
# Name: SalePrice, Length: 1758, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Separate numerical and categorical columns.

# %%
numerical = x.select_dtypes(include=['int64','float64'])
categorical = x.select_dtypes(include=['object'])

# %% [markdown]
# #Create overall pipeline code.

# %%
num_trans = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
])
cat_trans =Pipeline(
    steps=[
        ("imputer",SimpleImputer(strategy='most_frequent')),
        ("onehot",OneHotEncoder(handle_unknown='ignore'))
    ]
)
preprocessor = ColumnTransformer(
    transformers=[
        ('num',num_trans,numerical.columns),
        ('cat',cat_trans,categorical.columns)

    ]
)

# %% [markdown]
# #Base model identify in details

# %%
# base model identify
lr=LinearRegression()
Elas=ElasticNet(alpha=0.1)
Sgd=SGDRegressor(loss='squared_error',max_iter=1000,alpha=0.001,random_state=42,eta0=0.01)
svr=SVR(max_iter=100,gamma=0.1,kernel='rbf',C=0.6,degree=3)
Rg=RandomForestRegressor(n_estimators=100,criterion='squared_error',min_samples_leaf=2,min_samples_split=3,max_features='sqrt',random_state=42)
Gb=GradientBoostingRegressor(n_estimators=100,loss='absolute_error',subsample=1,min_samples_leaf=3,max_features='sqrt',random_state=42)
Ada=AdaBoostRegressor(n_estimators=156,loss='linear',random_state=42)
Dtr=DecisionTreeRegressor(max_depth=3,min_samples_leaf=3,min_samples_split=3,random_state=42,criterion='absolute_error')
Knr=KNeighborsRegressor(n_neighbors=17,weights='distance',metric='minkowski')
XG=XGBRegressor(n_estimators=1000,
    learning_rate=0.03,
    max_depth=6,
    min_child_weight=1,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1,
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1)

# %%
stacking=StackingRegressor(
    estimators=[
         ('lr',lr),
         ('elas',Elas),
         ('Sgd',Sgd),
         ("svr",svr),
         ('Rg',Rg),
         ("GB",Gb),
         ("Ada",Ada),
         ("Dtr",Dtr),
         ('Knr',Knr),
         ('XG',XG)

    ],
   final_estimator=Ridge()
)


voting=VotingRegressor(
    estimators=[
         ('lr',lr),
         ('elas',Elas),
         ('Sgd',Sgd),
         ("svr",svr),
         ('Rg',Rg),
         ("GB",Gb),
         ("Ada",Ada),
         ("Dtr",Dtr),
         ('Knr',Knr)

    ]

)

# %%
model_to_train={
    'Logistic Regression' : lr,
    'Elas':Elas,
    "SGDRegressor":Sgd,
    "SVR":svr,
    "RandomForestRegressor":Rg,
    "GradientBoostingRegressor":Gb,
    "AdaBoostRegressor":Ada,
    'DecisionTreeRegressor':Dtr,
    "KNeighborsRegressor":Knr,
    "XGBRegressor":XG,
    "StackingRegressor":stacking,
    "VotingRegressor":voting


}

# %%
from sklearn.metrics import accuracy_score,r2_score
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
# Trainning pipe line
result=[]
for model_name,model in model_to_train.items():
    pipe=Pipeline(
        [("preprocessor",preprocessor),
        ("model",model)
        ]
    )
    pipe.fit(x_train,y_train)
    y_pred=pipe.predict(x_test)
    accuracy=r2_score(y_test,y_pred)
    result.append(
        {
            "model":model,
            'accuracy':accuracy
        }
    )

# %%
res=pd.DataFrame(result).sort_values(by='accuracy',ascending=False)
res
# Out:
#                                                 model  accuracy
# 10  StackingRegressor(estimators=[('lr', LinearReg...  0.928128
# 9   XGBRegressor(base_score=None, booster=None, ca...  0.927480
# 1                               ElasticNet(alpha=0.1)  0.906325
# 2          SGDRegressor(alpha=0.001, random_state=42)  0.902186
# 0                                  LinearRegression()  0.893736
# 5   ([DecisionTreeRegressor(criterion='friedman_ms...  0.874072
# 4   (DecisionTreeRegressor(max_features='sqrt', mi...  0.867460
# 11  VotingRegressor(estimators=[('lr', LinearRegre...  0.850472
# 8   KNeighborsRegressor(n_neighbors=17, weights='d...  0.823058
# 6   (DecisionTreeRegressor(max_depth=3, random_sta...  0.805974
# 7   DecisionTreeRegressor(criterion='absolute_erro...  0.679037
# 3                 SVR(C=0.6, gamma=0.1, max_iter=100) -0.080750

# %% [markdown]
# param_grid = {
#     'final_estimator__alpha': [0.01, 0.1, 1, 10, 100],
#     'passthrough': [True, False]
# }
# স্টাকিংয়ে ভালো পারফরম্যান্স করলে মূলত রিজের এই দুইটা প্যারামিটার দিয়ে ক্রস ভ্যালিডেশন করা হয় এবং গ্রিড সার্চ ইভি করা হয়।

# %%
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error
)
import numpy as np
import pandas as pd

# Training Pipeline
result = []

for model_name, model in model_to_train.items():

    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("model", model)
    ])

    pipe.fit(x_train, y_train)

    y_pred = pipe.predict(x_test)

    # Regression Metrics
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)

    result.append({
        "Model": model_name,
        "R2 Score": r2,
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse
    })

# Convert to DataFrame
res = pd.DataFrame(result).sort_values(
    by="R2 Score",
    ascending=False
)

res
# Out:
#                         Model  R2 Score           MAE           MSE  \
# 10          StackingRegressor  0.928128  13240.888340  4.456938e+08
# 9                XGBRegressor  0.927480  13548.894531  4.497144e+08
# 1                        Elas  0.906325  15620.113450  5.809023e+08
# 2                SGDRegressor  0.902186  15300.002993  6.065683e+08
# 0         Logistic Regression  0.893736  16090.651632  6.589669e+08
# 5   GradientBoostingRegressor  0.874072  16844.318930  7.809134e+08
# 4       RandomForestRegressor  0.867460  17852.680947  8.219135e+08
# 11            VotingRegressor  0.850472  19122.153027  9.272608e+08
# 8         KNeighborsRegressor  0.823058  20567.592855  1.097263e+09
# 6           AdaBoostRegressor  0.805974  25751.949383  1.203207e+09
# 7       DecisionTreeRegressor  0.679037  30682.454545  1.990374e+09
# 3                         SVR -0.080750  62926.052233  6.702004e+09
#
#             RMSE
# 10  21111.462498
# 9   21206.470711
# 1   24101.915592
# 2   24628.607822
# 0   25670.351510
# 5   27944.828533
# 4   28669.034052
# 11  30450.958081
# 8   33124.953709
# 6   34687.278564
# 7   44613.612768
# 3   81865.766034

# %% [markdown]
# এখানে যেই মডেলটা সবচেয়ে ভালো করছে, তার ক্রস ভ্যালিডেশন করব।

# %%
xg_pipeline= Pipeline(
    [
        ('preprocessor',preprocessor),
        ('model',XG)
    ]
)

# %%
# Cross validation
cv_result=cross_val_score(xg_pipeline,x_train,y_train,cv=5,scoring='r2')

cv_acc=cv_result.mean()
cv_std=cv_result.std()

cv_acc,cv_std,cv_result
# Out:
# (np.float64(0.8959450721740723),
#  np.float64(0.02987175950500175),
#  array([0.90212345, 0.93046594, 0.84011346, 0.90330565, 0.90371686]))

# %% [markdown]
# fine tunning of xg boost

# %%
param_grid = {
    "model__n_estimators": [200, 500, 900, 1000, 1100],
    "model__learning_rate": [0.04, 0.1, 0.2, 0.3, 0.5],
    "model__max_depth": [2, 3, 4, 5, 6],
    "model__min_child_weight": [1, 2, 3, 4, 5],
    "model__subsample": [0.4, 0.5, 0.8, 1.0],
    "model__colsample_bytree": [0.5, 0.8, 1.0],
    "model__reg_alpha": [0.1, 0.2, 0.5],
    "model__reg_lambda": [1, 2, 4]
}

# %%
grid=GridSearchCV(
    estimator=xg_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='r2',
    n_jobs=-1,
    verbose=1

)

# %% [markdown]
# এইখানে যদি স্কোরিং আর টু না হয়ে অন্য কিছু হতো, তাহলে এই কোডটি লিখতাম।
# # R²
# scoring="r2"
#
# # MSE
# scoring="neg_mean_squared_error"
#
# # RMSE
# scoring="neg_root_mean_squared_error"
#
# # MAE
# scoring="neg_mean_absolute_error"

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 67500 candidates, totalling 337500 fits

# %%
print(grid.best_params_)
print(grid.best_score_)

model = grid.best_estimator_

# %%
preds=model.predict(test_df)
submission=pd.Dataframe(
    {
        'PID':test_ids,
        'SalePrice':preds
    }
)
submission.to_csv('submission.csv',index=False)
